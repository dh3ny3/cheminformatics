# %%
"""
Day 01: Variables and Drug Description
======================================================
SYNTAX:
    variable_name = value       # Assignment (=)
    f"text {variable}"          # F-string formatting
    
CHEMISTRY:
    - Molecular Weight (MW): Mass of molecule in g/mol (float)
    - LogP: Oil/water partition coefficient; measures lipophilicity (float)
    - HBD/HBA: Hydrogen bond donors/acceptors; count of polar groups (int)
    - SMILES: Text-based molecular structure representation (str)
"""

# %%
#storing drug information
drug_name = "Aspirin"
molecular_weight = 180.16
double_mw = molecular_weight * 2
is_active = True
num_atoms = 21
log_p = 1.19

print(f"Drug: {drug_name}")
print(f"Molecular Weight: {molecular_weight}")
print(f"Double the MW: {double_mw}")
print(f"Is Active? {is_active}")
print(f"Number of Atoms: {num_atoms}")
print(f"log P Value: {log_p}")
# Out:
# Drug: Aspirin
# Molecular Weight: 180.16
# Double the MW: 360.32
# Is Active? True
# Number of Atoms: 21
# log P Value: 1.19
